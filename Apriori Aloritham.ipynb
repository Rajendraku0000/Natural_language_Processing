# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\rajen\\OneDrive\\Desktop\\data\\market_basket.csv",header=None)

# %%
df
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
df.shape
# Out:
# (7501, 20)

# %%
transaction=[]
for i in range(0,7501):
    transaction.append([str(df.values[i,j]) for j in range (0,20)])

# %%
# !pip install apyori
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5975 sha256=f980a0441427a52df5dd742e1eefb138b98ff384e6fb340df71217867cb38ed5
#   Stored in directory: c:\users\rajen\appdata\local\pip\cache\wheels\84\45\a4\8ade6576f75410d8162c6da1de0aa9df56c16c711acab5a813
# Successfully built apyori
# ...

# %%
from apyori import apriori
rules=apriori(transaction,
             min_support=0.003,    #(3 items * 7 days in week )/(total rows in df)
             min_confidence=0.2,
             min_left=3,
             min_lenght=2)

# %%
rules
# Out:
# <generator object apriori at 0x0000026753E78F20>

# %%
a=list(rules)

# %%
a
# Out:
# [RelationRecord(items=frozenset({'mineral water'}), support=0.23836821757099053, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'mineral water'}), confidence=0.23836821757099053, lift=1.0)]),
#  RelationRecord(items=frozenset({'nan'}), support=0.9998666844420744, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=0.9998666844420744, lift=1.0)]),
#  RelationRecord(items=frozenset({'burgers', 'almonds'}), support=0.005199306759098787, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'burgers'}), confidence=0.25490196078431376, lift=2.923577382023146)]),
#  RelationRecord(items=frozenset({'almonds', 'chocolate'}), support=0.005999200106652446, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'chocolate'}), confidence=0.29411764705882354, lift=1.7950988369310295)]),
# ...

# %%
result=[list(a[i][0]) for i in range(0,len(a))]

# %%
result
# Out:
# [['mineral water'],
#  ['nan'],
#  ['burgers', 'almonds'],
#  ['almonds', 'chocolate'],
#  ['eggs', 'almonds'],
#  ['french fries', 'almonds'],
#  ['green tea', 'almonds'],
#  ['milk', 'almonds'],
#  ['mineral water', 'almonds'],
#  ['nan', 'almonds'],
#  ['almonds', 'spaghetti'],
#  ['antioxydant juice', 'nan'],
#  ['nan', 'asparagus'],
#  ['chocolate', 'avocado'],
#  ['french fries', 'avocado'],
#  ['milk', 'avocado'],
#  ['mineral water', 'avocado'],
#  ['nan', 'avocado'],
#  ['avocado', 'spaghetti'],
#  ['babies food', 'nan'],
#  ['mineral water', 'bacon'],
#  ['nan', 'bacon'],
#  ['bacon', 'spaghetti'],
#  ['barbecue sauce', 'eggs'],
#  ['mineral water', 'barbecue sauce'],
#  ['barbecue sauce', 'nan'],
#  ['eggs', 'black tea'],
#  ['milk', 'black tea'],
#  ['mineral water', 'black tea'],
#  ['nan', 'black tea'],
#  ['black tea', 'spaghetti'],
#  ['mineral water', 'blueberries'],
#  ['nan', 'blueberries'],
#  ['blueberries', 'spaghetti'],
#  ['french fries', 'body spray'],
# ...

# %%
a[0][0]
# Out:
# frozenset({'mineral water'})

# %%
a[0]
# Out:
# RelationRecord(items=frozenset({'mineral water'}), support=0.23836821757099053, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'mineral water'}), confidence=0.23836821757099053, lift=1.0)])

# %%
a[0][1]
